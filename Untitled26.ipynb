# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjana323/NLP/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob
Text1="I love this product & it is good"
blob1=TextBlob(Text1)
sentiment1=blob1.sentiment.polarity

# %%
print("=" * 60)
print("TEXT 1:", Text1)
print(f"Sentiment Score: {sentiment1:.2f}")
# Out:
# ...
# TEXT 1: I love this product & it is good
# Sentiment Score: 0.60

# %%
if sentiment1 > 0:
    print("positive😂")
else:
    print("negtive😒")
# Out:
# positive😂
